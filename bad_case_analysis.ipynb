# %% [markdown]
# ## 训练集和测试集

# %%
import pandas as pd
TRAIN_PATH = '/project1/liqingshan/NLP/NER/Data/train.csv'
TEST_PATH = '/project1/liqingshan/NLP/NER/Data/test.csv'
test_data = pd.read_csv(TEST_PATH)
train_data = pd.read_csv(TRAIN_PATH)
train_data
# Out:
#       Unnamed: 0  index    id                                      text  \
# 0              0   1505  1505                     挺快的了，我是8月底下的卡，今年51提的。
# 1              1   1506  1506                我显示汇总过高了，今天下了中信4万，准备把招商注销了
# 2              2   1507  1507                                  刷超市银行利润低
# 3              3   1508  1508                           你这个网速是怎么加的呢，慢死了
# 4              4   1509  1509  我12月份下的卡，一直有临额今天到期临时额度没有了，这个月刚好是调额月，怕进黑屋
# ...          ...    ...   ...                                       ...
# 6018        6018   7523  7523                                     我鼎级拒了
# 6019        6019   7524  7524              一打一个准，准胜，看激活信用卡时那协议，全是对银行有利的
# 6020        6020   7525  7525                                  招行分期白80k
# 6021        6021   7526  7526                              5万，额度还行吧没毕业哦
# 6022        6022   7527  7527                         张家港农商、江阴农商、无锡农商试试
#
#                                                BIO_anno  class
# 0     B-COMMENTS_ADJ I-COMMENTS_ADJ O O O O O O O O ...      2
# 1     O O O O O B-COMMENTS_ADJ I-COMMENTS_ADJ O O O ...      2
# 2                          O O O O O O O B-COMMENTS_ADJ      2
# 3            O O O O O O O O O O O O B-COMMENTS_ADJ O O      2
# 4     O O O O O O O B-PRODUCT O O O O B-COMMENTS_N I...      2
# ...                                                 ...    ...
# 6018                             O O O B-COMMENTS_ADJ O      2
# 6019  O O O O O O O O O O B-COMMENTS_N I-COMMENTS_N ...      2
# 6020  B-BANK I-BANK B-PRODUCT I-PRODUCT I-PRODUCT O O O      2
# 6021      O O O B-COMMENTS_N I-COMMENTS_N O O O O O O O      2
# 6022  B-BANK I-BANK I-BANK I-BANK I-BANK O B-BANK I-...      2
#
# [6023 rows x 6 columns]

# %% [markdown]
# ## 导入模型参数

# %%
import torch 
import torch.nn as nn
from transformers import BertModel, AutoTokenizer
from torchcrf import CRF
BERT_PATH = '/project1/liqingshan/NLP/Models/bert-base-chinese'
HIDDEN_SIZE = 256
DROPOUT = 0.2
LABEL_SIZE = 9
model_saved_path = '/project1/liqingshan/NLP/NER/Data/D_BERT_BiLSTM_CRF/_weights.bin'
class Bert_Model(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        
        self.bert = BertModel.from_pretrained(BERT_PATH, output_hidden_states=True)
        self.fc1 = nn.Linear(12*768, 768)       # weight merge
        self.lstm = nn.LSTM(
            768,
            HIDDEN_SIZE,
            batch_first = True,
            bidirectional = True
        )
        self.dropout = nn.Dropout(DROPOUT)
        self.fc2 = nn.Linear(HIDDEN_SIZE*2, LABEL_SIZE)
        self.crf = CRF(LABEL_SIZE, batch_first=True)
        
    def forward(self, input_ids, labels=None, mask=None):
        att_mask = torch.ne(input_ids, 0)
        bert_output = self.bert(input_ids, attention_mask=att_mask)
        hidden_states = bert_output[2][1:]  # 除去embdding层
        B, S, _ = hidden_states[0].shape    # batch_size, seq_len, embed_dim
        hidden_states = torch.stack(hidden_states, dim=3)   # 把新维度放到最后: (batch_size, seq_len, embed_dim, num_layers=12)
        hidden_states = hidden_states.view(B, S, -1)    
        # hidden_states： （batch_size, seq_len, 12*embed_dim)
        sequence_output = self.fc1(hidden_states)
        sequence_output = self.dropout(sequence_output)
        # sequence_output: (batch_size, sequence_length, embed_dim=768)
        sequence_output, _ = self.lstm(sequence_output)
        # sequence_output: (batch_size, seq_len, HIDDEN_SIZE*2)
        logits = self.fc2(sequence_output)
        # logits: (batch_size, seq_len, LABEL_SIZE=9)
        tags = self.crf.decode(logits, att_mask)
        # tags: List of list containing the best tag sequence for each batch.
        
        return tags 
    
    def loss_fn(self, input_ids, label_ids, mask):
        att_mask = torch.ne(input_ids, 0)
        bert_output = self.bert(input_ids, attention_mask=att_mask)
        hidden_states = bert_output[2][1:]  # 除去embdding层
        B, S, _ = hidden_states[0].shape    # batch_size, seq_len, embed_dim
        hidden_states = torch.stack(hidden_states, dim=3)   # 把新维度放到最后: (batch_size, seq_len, embed_dim, num_layers=12)
        hidden_states = hidden_states.view(B, S, -1)    
        # hidden_states： （batch_size, seq_len, 12*embed_dim)
        sequence_output = self.fc1(hidden_states)
        sequence_output = self.dropout(sequence_output)
        # sequence_output: (batch_size, sequence_length, embed_dim=768)
        sequence_output, _ = self.lstm(sequence_output)
        # sequence_output: (batch_size, seq_len, HIDDEN_SIZE*2)
        logits = self.fc2(sequence_output)
        # logits: (batch_size, seq_len, LABEL_SIZE=9)
        if label_ids != None:
            loss = self.crf(logits, label_ids, att_mask)
        return loss*(-1)  

model = Bert_Model()
model.load_state_dict(torch.load(model_saved_path))
# Out:
# Some weights of the model checkpoint at /project1/liqingshan/NLP/Models/bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %% [markdown]
# ## 创建Dataloader

# %%
import torch.utils.data as data
LABEL_PATH = '/project1/liqingshan/NLP/NER/Data/label.txt'
VOCAB_PATH = '/project1/liqingshan/NLP/NER/Data/vocab.txt'
LABEL_PAD_ID = 0
BERT_PAD = '[PAD]'
BATCH_SIZE = 2
class Dataset_Bert(data.Dataset):
    def __init__(self, data) -> None:
        super().__init__()
        self.data = data
    
    def get_dict(self, dict_path):
        '''
        将存起来的labels文件转化成字典映射
        '''
        assert dict_path in [VOCAB_PATH, LABEL_PATH], 'wrong path!'
        df = pd.read_csv(dict_path, names=['char', 'id'])
        mapping = {}
        for i in range(1, len(df)):
            mapping[df['char'][i]] = df['id'][i]
        return mapping
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        text = self.data['text'][idx]
        labels = self.data['BIO_anno'][idx]
        label2id = self.get_dict(LABEL_PATH)
        label_num = [int(label2id.get(v, LABEL_PAD_ID)) for v in labels.split(' ')]
        assert len(text) == len(label_num)
        return text, label_num

def get_bert_dataloader(data_set, tokenizer):
    def collate_fn(batch_samples):
        batch_samples.sort(key = lambda x:len(x[0]), reverse=True)
        max_len = len(batch_samples[0][0])      # 当前批次最长序列长度
        batch_text, batch_label = [], []
        for sample in batch_samples: 
            pad_len = max_len - len(sample[0])    # pad长度
            text = sample[0] + pad_len*BERT_PAD
            batch_text.append(text)
            
            label_ids = [LABEL_PAD_ID]+sample[1] + [LABEL_PAD_ID]*pad_len+[LABEL_PAD_ID]
            batch_label.append(label_ids)
            
        text_dic = tokenizer(batch_text, padding=True, truncation=True, return_tensors='pt', max_length=256)
        input_ids = text_dic['input_ids']
        assert len(batch_text) == len(batch_label), f'input: {len(batch_text)}, label: {len(batch_label)}'
        
        return input_ids, torch.tensor(batch_label, dtype=torch.long), torch.tensor(1)
            
    dataset = Dataset_Bert(data_set)
    dataloader = data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, collate_fn=collate_fn)
    return dataloader

# %% [markdown]
# ## 坏例分析

# %%
tokenizer = AutoTokenizer.from_pretrained(BERT_PATH)
train_dataloader = get_bert_dataloader(train_data, tokenizer)
labelid2label = {0:'O', 1:'I-PRODUCT', 2:'B-COMMENTS_ADJ', 3:'I-COMMENTS_N', 4:'B-COMMENTS_N',
                5:'B-PRODUCT', 6:'I-COMMENTS_ADJ', 7:'I-BANK', 8:'B-BANK'}
wrong_samples = {'O':0, 'I-PRODUCT':0, 'B-COMMENTS_ADJ':0, 'I-COMMENTS_N':0, 'B-COMMENTS_N':0, 
                'B-PRODUCT':0, 'I-COMMENTS_ADJ':0, 'I-BANK':0, 'B-BANK':0}
from sklearn.metrics import confusion_matrix
def testing(dataloader, model):
    model.eval()
    Y_pred, Label = [], []
    with torch.no_grad():
        for batch, (input_ids, label_ids, mask) in enumerate(dataloader):
            y_pred = model(input_ids, mask)
            # 把y_pred填充成label_ids 的形状
            max_len = len(label_ids[0])
            for row in y_pred:
                if len(row) < max_len:
                    row += [LABEL_PAD_ID]*(max_len-len(row))
            y_pred = torch.tensor(y_pred).flatten().cpu()
            Y_pred += y_pred.tolist()
            label_ids = label_ids.flatten().cpu()
            Label += label_ids.tolist()
    return Y_pred, Label
y_pred, label = testing(train_dataloader, model)

# %%
conf_mat = confusion_matrix(label, y_pred)
conf_mat
# Out:
# array([[186709,    221,    306,    147,    132,    211,    240,     59,
#             49],
#        [   186,   4773,      1,     22,      2,     48,      1,      5,
#              2],
#        [   312,      1,   3499,      3,      3,      0,     43,      0,
#              1],
#        [   200,      7,      5,   3509,     49,      2,      2,      0,
#              0],
#        [   168,      1,      4,     35,   3313,      9,      1,      0,
#              0],
#        [   142,     44,      2,      2,     24,   3268,      0,      5,
#              2],
#        [   305,      2,     36,      0,      5,      2,   2902,      0,
#              1],
#        [    55,      4,      1,      0,      0,      2,      1,   2435,
#             21],
#        [    50,      1,      1,      0,      0,      1,      0,     15,
#           1987]])

# %%
import matplotlib.pyplot as plt
import numpy as np
row_sums = conf_mat.sum(axis=1, keepdims=True)   # 标准化一下，否则量纲相差太大
norm_conf_mat = conf_mat/row_sums
np.fill_diagonal(norm_conf_mat, 0)
plt.matshow(norm_conf_mat, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# 观察上图可以发现，基本上错误都是将其他类别误判成了0（O），特别是6（I-COMMENTS_ADJ）和2（B-COMMENTS_ADJ），因此我们可以考虑对其他数据做数据增强以提升模型对其他数据的理解。
#
# 方法为统计所有除0（O）以外的其他数对应的实体名字，然后再随机替换。注意，我们不能只替换单个字符，而是应该替换整个实体，为此我们先统计所有种类的实体。

# %%
def get_row_entities(data, row, type):
    res = []
    label = data['BIO_anno'][row].split(' ')
    text = list(data['text'][row])
    for i, v in enumerate(label):       
        if res and v.startswith('I-'):      # 说明当前词在上一个实体的中间
            res[-1] += text[i]
        elif type in v:
            res.append(text[i])
    return res  
print(get_row_entities(train_data, 120, 'COMMENTS_ADJ'))        # 120行没有 'COMMENTS_ADJ'
print(get_row_entities(train_data, 0, 'COMMENTS_ADJ'))
# Out:
# []
# ['挺快']

# %% [markdown]
# 对所有行和所有类别进行此操作，把结果存起来备用。

# %%
entities = {'PRODUCT':[], 'COMMENTS_ADJ':[], 'COMMENTS_N':[], 'BANK':[]}
for row in range(len(train_data)):      # 所有行
    for type in ['PRODUCT', 'COMMENTS_ADJ', 'COMMENTS_N', 'BANK']:  # 所有类别
        entities[type] += get_row_entities(train_data, row, type)

# %%
for type in entities.keys():
    print(f'length of entity {type} is {len(entities[type])}')
# Out:
# length of entity PRODUCT is 3489
# length of entity COMMENTS_ADJ is 3862
# length of entity COMMENTS_N is 3534
# length of entity BANK is 2055

# %% [markdown]
# 接下来我们将每种实体按照长度分类：

# %%
for type in ['PRODUCT', 'COMMENTS_ADJ', 'COMMENTS_N', 'BANK']:
    entities[type].sort(key = lambda x : len(x), reverse=True)
    
PRODUCT, COMMENTS_ADJ, COMMENTS_N, BANK = {}, {}, {}, {}
for type in ['PRODUCT', 'COMMENTS_ADJ', 'COMMENTS_N', 'BANK']:
    for v in entities[type]:
        if len(v) in eval(type).keys():
            eval(type)[len(v)] += [v]
        else:
            eval(type)[len(v)] = [v]
PRODUCT
# Out:
# {22: ['信用卡国银行商银行业银行设银行安银行商银行错'],
#  17: ['line friends的信用卡度'],
#  13: ['分期债度行储通发信安海州苏'],
#  12: ['分期可以债商设行大行夏发',
#   '信用卡度少账度少息少谢期',
#   '魔都优逸白金信用卡卡较好',
#   '公安便民龙卡信用卡卡度度',
#   '微粒贷设业政商夏丰信生州'],
#  11: ['app了费准确费费准确', '招商银行星座守护信用卡', '信用卡支度产入产多入多', '钻石精英、无限visa'],
#  10: ['信用卡费户固额定额度',
#   '固定额度提升续费固定',
#   '香白3136环球双M',
#   '征信的很款行单优款款',
#   '美国运通百夫长信用卡',
#   '掌上生活app信银行',
#   '兴享贷清续费清业续费'],
#  9: ['首卡度时额度固定度',
#   '百夫长白金期卡费卡',
#   '信用卡时额度定额度',
#   'Young卡用卡卡',
#   '周五饭票五折通银行',
#   'Clear透明金卡',
#   '星座白金信用卡星级',
#   '积分厚行算度度低度',
#   '芭比白的信用卡本费',
#   '信用卡度坑卡度力度',
#   '信用卡信银行国银行',
#   '股票、期货、外汇险',
#   'niubility',
#   '阳光惠生活app卡'],
#  8: ['小白金费续费费费',
#   '掌上生活续费续费',
#   '现金分期期定额度',
#   '按期还钱务逾期准',
#   '掌上生活度信贷额',
#   '分期期度长能度度',
#   '卡片核过心度法能',
#   '炫萌萌白金信用卡',
#   '分期降债行大行发',
#   '融e借度度度度度',
#   '信用卡度期金息商',
#   'U盾想行须水少高',
#   '上交大复旦联名卡',
#   '标准白金卡额大难',
#   'applepay',
#   'i白金对销卡快了',
#   '信用卡度信控有款',
#   '动卡空间app好',
#   '客服好速好丰富欢',
#   '哔哩哔哩联名卡安',
#   '哔哩哔哩联名卡行',
#   '信用卡缴款现续费',
#   '白金卡币民币币费',
#   '鲁通卡设银行费费',
#   '信用卡业息长期款',
#   '中银e贷化通生信',
#   '手机银行APP活',
#   'applepay',
#   '犀利卡债高常费卡'],
#  7: ['储蓄卡需要好了',
#   '预约受理核核核',
#   'app度然核卡',
#   '分期能免息先息',
#   '积分香行行行水',
#   '信用卡款度息款',
#   '拉卡拉额额妥额',
#   '信用卡付付续费',
#   '菜卡卡烦卡所谓',
#   '分期续费别高化',
#   '信用卡度常稳定',
#   '分期债行信安行',
#   '无界数字卡度费',
#   '信用卡批多卡难',
#   '上海旅行白金卡',
#   '南航白行行州行',
#   '云闪付款续费到',
#   '国家宝藏信用卡',
#   '花呗销行度行度',
#   '白金卡度懂活销',
#   '网捷贷期特么难',
#   '网捷贷度小了息',
#   '精粹白度点低卡',
#   '信用卡度七八糟',
#   '001白金低度',
#   'safari卡',
#   '惠民贷高审批度',
#   '首卡度度低销销',
#   '分期低款额款额',
#   '征信商卡信必要',
#   '华为卡信付宝现',
#   '圆梦金信度过了',
#   '信用卡白信银行',
#   '手机银行app',
#   'young卡额',
#   '信用卡款圾款气',
#   '交通信用卡高度',
#   '年费免衡度卡易',
#   '故宫金卡度卡惜',
#   '信用卡度押产入',
#   '哔哩哔哩会员虑',
#   '信用卡卡未激活',
#   '全球支付白金度',
#   '信用卡单日款日',
#   '信用卡活活款额',
#   '卡度低额高度额',
#   '信用卡圾国银行',
#   '信用卡怎么样销',
#   '口袋银行APP',
#   '产品卡业不可及',
#   '储蓄卡能能销水',
#   '卓越孝心白少度',
#   '卓越孝心白活费',
#   '圆梦金低化通单'],
#  6: ['卡额期时额度',
#   '掌上生活续费',
#   'app续费能',
#   'young卡',
#   'young卡',
#   '现金分期度度',
#   '财智金发大直',
#   'app度卡有',
#   '分期还款额息',
#   '手机银行简单',
#   '征信单日款低',
#   '征信行高信高',
#   '京东小白卡易',
#   '征信塌糊涂多',
#   '标准金卡提错',
#   '经典白信好信',
#   '云闪付费行行',
#   '支付宝稳谱逼',
#   '菜卡好信卡谢',
#   '公积金商银行',
#   '经典白误兴兴',
#   '卡多商银行好',
#   '征信账期少少',
#   '征信账户期期',
#   '信用卡活活活',
#   'visa付照',
#   '实体卡心活活',
#   '浦惠久久率错',
#   '融e借度少度',
#   '信用卡行喜行',
#   '房贷信了较小',
#   '十二宫图卡活',
#   '信用卡批不如',
#   '信用卡额行额',
#   '分期续费单单',
#   '征信定卡行卡',
#   '无界卡能销行',
#   '分期款高于款',
#   '白金卡费高了',
#   '信用卡商大大',
#   '征信期少债批',
#   '环球双标M久',
#   '光芒金卡喜欢',
#   '全球支付白州',
#   'app费行费',
#   '信用卡控能行',
#   '云闪付款续费',
#   '征信行行较难',
#   '白金卡么有乐',
#   '数字卡审批度',
#   '融e借能偏商',
#   '信用卡度够能',
#   '公务卡度高额',
#   '移动卡常户黑',
#   '积分国银行能',
#   '结算卡水事信',
#   'app活活活',
#   '卡额额额行了',
#   '按揭好期金期',
#   '房贷率高息金',
#   'First卡',
#   '精英白较慢了',
#   '分期于额利于',
#   'app试生试',
#   '香格里拉白金',
#   '标准白金卡核',
#   '标准白额难销',
#   '标准白金卡额',
#   '标准白金卡提',
#   '贷记卡少息息',
#   '金卡审批通期',
#   '惠民贷审批度',
#   '分期款息金息',
#   'batch卡',
#   '信用卡核恶心',
#   '分期能单额款',
#   '圆梦金单低息',
#   '大白金费卡卡',
#   '信用卡度复复',
#   '新快现度度度',
#   '信用卡商银行',
#   '信用卡不错度',
#   '信用卡商银行',
#   'first卡',
#   '白金销害辱强',
#   '积分商银行类',
#   '周三饭票五折',
#   '免息长通银行',
#   '现金分期度度',
#   '信用卡便具失',
#   '信用卡度高信',
#   '信用卡度高信',
#   '银联分期白金',
#   'JOY信用卡',
#   'JCB日元卡',
#   '信用卡额力心',
#   '信用卡刷死行',
#   '信用卡业银行',
#   '牡丹交通卡度',
#   '白户度大银行',
#   '闪电现金贷发',
#   '信用卡费人骗',
#   '全球热购路活',
#   '分期乐信期好',
#   '信用卡请请请',
#   '卡南航联名卡',
#   '信用卡支度高',
#   '流水储蓄信度',
#   '信用卡用记录',
#   '龙卡益贷度高',
#   '还款日款期期',
#   '标准金卡度意',
#   '颜卡信银行行',
#   '信用卡现续费',
#   '国航世界卡信',
#   '信用卡信发坑',
#   '信用卡信银行',
#   '支付宝政银行',
#   'BNBTC慎',
#   'app度行吧',
#   '分期安续费单',
#   '好车主金卡到',
#   'DIY能能有',
#   '好车主白金卡',
#   '无界卡行卡卡',
#   '鼎致卡债多啦',
#   '理财益动动大',
#   'EMS联名卡',
#   '大白金高度能',
#   '信用卡度高足',
#   '储蓄卡政水然'],
#  5: ['储蓄卡销销',
#   '信用卡业业',
#   '京东小白卡',
#   '黄金卡不多',
#   '私行卡产益',
#   '积分无压力',
#   '分期额度至',
#   '现金分期度',
#   '现金分期额',
#   '预借现金卡',
#   '预借现金单',
#   '分期费问题',
#   '信用卡度好',
#   '白金卡卡度',
#   '个性化分期',
#   '分期续费金',
#   '分期还款单',
#   '信用卡难力',
#   '征信行高信',
#   '掌上生活行',
#   '网贷卡所谓',
#   '支付宝较好',
#   '分期额行行',
#   '分期能低息',
#   '征信债大难',
#   '高尔夫白生',
#   '征信多卡行',
#   '储蓄卡款惜',
#   '公积金好前',
#   '星座卡错哦',
#   '小招Pu卡',
#   '大白金核度',
#   '经典白有卡',
#   '经典白付消',
#   '信用卡债期',
#   '积分商费费',
#   '金葵花悠悠',
#   'e招贷易度',
#   '支付宝稳定',
#   '钻石卡安快',
#   '朝朝盈错的',
#   '微加卡烦谢',
#   '信用卡度力',
#   '公积金卡度',
#   '经典白多了',
#   '二类卡度了',
#   '大白金意义',
#   '征信户喜欢',
#   '分期少越好',
#   '征信户期行',
#   '信用卡度批',
#   '信用卡度然',
#   '分期能款少',
#   '小米支付多',
#   '征信所谓卡',
#   '二卡度低低',
#   '分期债行大',
#   '信用卡度好',
#   '无界卡确定',
#   '首卡额额额',
#   '信用卡有期',
#   '分期续费户',
#   '云闪付行行',
#   '征信的净棒',
#   '生肖白费费',
#   'mini费',
#   '香白户多够',
#   '香白活费费',
#   '分期续费单',
#   '分期化行率',
#   '分期款续费',
#   '信用卡烈销',
#   '信用卡烈销',
#   '无界卡核住',
#   '网贷期好错',
#   '分期难度高',
#   '融e借度度',
#   '信用卡度度',
#   '理财期期商',
#   '首卡户卡户',
#   '分期少额心',
#   '白金卡白明',
#   '信用卡稳定',
#   '优客分期商',
#   '云闪付发怪',
#   '生肖白费定',
#   '云闪付行额',
#   '快贷易单易',
#   '融e借然行',
#   '生肖金卡够',
#   '奋斗白金卡',
#   '星座白金卡',
#   '半岛菁英白',
#   '小白金清楚',
#   '白金卡费额',
#   '银行数字卡',
#   '信用卡度少',
#   '无界卡度变',
#   '征信行度久',
#   '卡业银行慢',
#   'app行惠',
#   '支付宝续费',
#   '云闪付方便',
#   '信用卡有度',
#   '信用卡度额',
#   '融e借度度',
#   '信用卡度额',
#   '融e借问题',
#   '广百白金卡',
#   '征信度单额',
#   '征信少行常',
#   '信用卡款单',
#   '信用卡低度',
#   '工银e生活',
#   '信用卡简单',
#   '信用卡额款',
#   '房贷期账白',
#   '简约白金费',
#   '星座卡户爽',
#   '工银e生活',
#   '信用卡易批',
#   '信用卡度少',
#   '分期能销妥',
#   '无界白度销',
#   '征信账心期',
#   '公务卡能能',
#   '国贸香白活',
#   'Mc环球金',
#   '信用卡高度',
#   '白金emv',
#   '首卡国银行',
#   '信用卡度有',
#   '分期额费费',
#   '奥运会卡白',
#   'U盾行行行',
#   '自由行卡懵',
#   'II卡批常',
#   'app额少',
#   '二卡活活行',
#   '乐享七天益',
#   '信用卡批额',
#   '房贷浮好多',
#   '分期能能期',
#   '公积金太好',
#   '宝藏卡度高',
#   '储蓄卡审批',
#   '征信卡活额',
#   '信用卡度少',
#   '分期卡不多',
#   '积分本低本',
#   '圆梦金便宜',
#   '百夫长低度',
#   '公积金到生',
#   '信用卡度度',
#   '征信信加信',
#   '信用卡度费',
#   '分期生费额',
#   '白金卡额难',
#   '标准白金卡',
#   '云闪付额额',
#   '信用卡常卡',
#   '民生卡度度',
#   '分期度度常',
#   '积分卡度额',
#   '惠民贷行度',
#   'app付卡',
#   '信用卡费批',
#   '信用卡期能',
#   '分期续费金',
#   '信用卡度费',
#   '白金卡度级',
#   '公积金债少',
#   '信用卡能信',
#   '白金卡级级',
#   '信用卡少度',
#   '信用卡功过',
#   '圆梦金惨了',
#   '普卡级额度',
#   '信用卡款款',
#   '掌上生活好',
#   '支付宝口碑',
#   '大众点评多',
#   '信用卡高度',
#   '悦卡金卡度',
#   '最红星期五',
#   '手机银行好',
#   '信用卡度行',
#   '现金分期额',
#   '墨蓝宇宙卡',
#   '账单度额快',
#   '固定额度额',
#   '控制负债率',
#   '信用卡少少',
#   '信用卡障残',
#   '香格里拉白',
#   '长隆信用卡',
#   '征信报告喜',
#   '白金信用卡',
#   '臻尚白金卡',
#   '信用卡批用',
#   '无界数字卡',
#   '无界白金卡',
#   '普通卡度高',
#   '利息度黑了',
#   '信用卡行度',
#   '信用卡度额',
#   '信用卡骗发',
#   '还款日狂收',
#   '全球支付卡',
#   '公积金卡行',
#   '信用卡度销',
#   '信用卡成功',
#   '信用卡签签',
#   '信用卡掉费',
#   '网贷期信行',
#   '龙卡JOY',
#   '信用卡度额',
#   '信用卡活费',
#   'etc现行',
#   '知音白金卡',
#   '信用卡多信',
#   '大山白度限',
#   '公务卡额行',
#   '信用卡掉行',
#   '信用卡批度',
#   '双币白金惠',
#   '信用卡好好',
#   '大山白费搞',
#   '信用卡度低',
#   'i白金信信',
#   '信用卡码功',
#   'app额度',
#   '卡活信能信',
#   '支付宝费奖',
#   '信用卡度错',
#   '白金卡好看',
#   '拜仁卡好请',
#   '余额宝多了',
#   '金卡励金高',
#   '实体卡片常',
#   '信用卡政行',
#   '京东联名卡',
#   '百夫长活到',
#   '房贷发银行',
#   '分期续费费',
#   '分期债高控',
#   '虚拟卡活活',
#   '分期额度烦',
#   '好车主金卡',
#   '下卡度慢高',
#   '支付宝费奖',
#   '信用卡度度',
#   '鼎雅能点度',
#   '余额宝全定',
#   '分期低续费',
#   '百度广发卡',
#   '信用卡费费',
#   '网贷能卡度',
#   '公积金高储'],
#  4: ['掌上生活',
#   '洛天依有',
#   '鸟白费费',
#   '百夫长傲',
#   '自由白户',
#   '分期少化',
#   '申卡商行',
#   '储蓄卡行',
#   '支付宝付',
#   '支付宝行',
#   '信用卡度',
#   '滞纳金额',
#   '征信合理',
#   '私行卡多',
#   '分期付款',
#   '挂账分期',
#   '挂账分期',
#   '卡能率低',
#   '经典白易',
#   '金卡额联',
#   '掌上生活',
#   '预约分期',
#   '金卡额额',
#   '掌上生活',
#   '鸟白看了',
#   'app行',
#   '掌上生活',
#   '征信额度',
#   '花呗能费',
#   '明日贷错',
#   '金卡好核',
#   '信用卡骗',
#   '分期得了',
#   '金葵花欢',
#   '卡多能能',
#   '逾期单单',
#   'e招贷久',
#   '还款日款',
#   '白金卡度',
#   '征信核核',
#   '理财信额',
#   '天天基金',
#   '活期宝行',
#   '云闪付额',
#   '信用卡款',
#   '金葵花够',
#   '金葵花有',
#   '黄金卡易',
#   '京东金融',
#   '征信核假',
#   '支付宝商',
#   'E分期额',
#   '掌上生活',
#   '信用卡行',
#   '支付宝有',
#   '公积金能',
#   '单币卡户',
#   'E分期额',
#   '京东金融',
#   '主卡户商',
#   '金卡度少',
#   '支付宝控',
#   '菜卡简单',
#   '分期能额',
#   '提额所谓',
#   '掌上生活',
#   '分期续费',
#   '信用卡高',
#   'visa',
#   '定期期诉',
#   '工资卡行',
#   '储蓄卡活',
#   '储蓄卡商',
#   '卡发可以',
#   '支付宝款',
#   '普卡度点',
#   '经典白易',
#   '百夫长费',
#   '经典白卡',
#   '积分奖卡',
#   '支付宝付',
#   '积分续费',
#   '信用卡行',
#   '金葵花悠',
#   '信用卡期',
#   '信用卡好',
#   '云闪付烦',
#   '金葵花看',
#   '分期度度',
#   'visa',
#   '信用卡重',
#   '信用卡度',
#   '社保卡行',
#   '分期续费',
#   '菜卡得销',
#   '信用卡圾',
#   '储蓄卡度',
#   'visa',
#   '信用卡息',
#   '菜卡销心',
#   '校园卡度',
#   '新快现发',
#   '征信能低',
#   '网贷期卡',
#   '信用卡户',
#   '信用卡度',
#   '公积金权',
#   '工资卡躁',
#   '卡快通期',
#   '苹果支付',
#   '华为支付',
#   '实体卡心',
#   'visa',
#   'visa',
#   '公积金行',
#   '信用卡度',
#   '融e借度',
#   '融e借度',
#   '信用卡额',
#   '融e借度',
#   '理财不多',
#   '征信好商',
#   '信用卡度',
#   '分期行能',
#   '白金卡欢',
#   '信用卡期',
#   '信用卡额',
#   '融e借户',
#   '信用卡能',
#   '单币卡费',
#   '白金卡卡',
#   '公积金行',
#   '大白金力',
#   '融e借久',
#   '融e借少',
#   '实体卡累',
#   '融e借少',
#   '融e借权',
#   '融e借息',
#   '首卡不多',
#   '信用卡喜',
#   '信用卡多',
#   '信用卡多',
#   '征信卡秀',
#   '大额卡难',
#   '白麒麟卡',
#   '无界卡批',
#   '融e借度',
#   'mini',
#   '分期续费',
#   '工行卡核',
#   '平仓卡全',
#   '理财好呀',
#   '信用卡级',
#   '储蓄卡行',
#   '二卡续费',
#   '信用卡度',
#   '分期续费',
#   '融e借期',
#   '卡度能额',
#   '信用卡度',
#   '信用卡度',
#   '融e借度',
#   '融e借度',
#   '信用卡度',
#   '信用卡度',
#   '理财久久',
#   '首卡度错',
#   '信用卡度',
#   '信用卡误',
#   '信用卡费',
#   '星座金卡',
#   'app快',
#   '白金卡户',
#   'app丑',
#   '单币卡难',
#   '步步为赢',
#   '信用卡度',
#   'visa',
#   '菜卡行发',
#   '菜卡亮度',
#   '分期通行',
#   '储蓄卡少',
#   '菜卡意义',
#   '生肖白费',
#   '征信期期',
#   '银行卡低',
#   '储蓄卡安',
#   '信用卡款',
#   '云闪付能',
#   '掌上生活',
#   'app常',
#   '卡商银行',
#   '快贷度下',
#   '医护卡能',
#   'app假',
#   '信用卡度',
#   '微众卡能',
#   'U盾所谓',
#   '信用卡户',
#   '国航白误',
#   '国航白要',
#   '大白金费',
#   'visa',
#   '南航白行',
#   '悠然白行',
#   '生肖金行',
#   '房贷行核',
#   '好车主服',
#   '信用卡付',
#   '银行卡难',
#   '借记卡款',
#   '支付宝款',
#   '云闪付还',
#   '信用卡度',
#   '融e借度',
#   '贷款质高',
#   '信用卡度',
#   '信用卡度',
#   '融e借额',
#   '融e借能',
#   '融e借额',
#   '信用卡度',
#   '瑞鹤千秋',
#   '分期度单',
#   '信用卡度',
#   '分期款度',
#   '无界卡少',
#   '卡远弃多',
#   '贷款费户',
#   '信用卡户',
#   '负债卡多',
#   '积分值钱',
#   '积分付额',
#   '网贷户户',
#   '信用卡行',
#   '账单行朗',
#   '征信常期',
#   '信用卡常',
#   '融e借常',
#   '普卡度费',
#   '信用卡怕',
#   '融e借行',
#   '融E借额',
#   '征信账期',
#   '分期单惠',
#   '分期繁绝',
#   '生肖白销',
#   '实体卡喜',
#   '公积金点',
#   '融e借度',
#   '融e借妥',
#   '分期能少',
#   '信用卡度',
#   '信用卡度',
#   '分期通行',
#   '白金卡额',
#   '白金卡度',
#   '白金卡度',
#   '征信批销',
#   '二卡销心',
#   '闪付续费',
#   '双标联联',
#   '积分能付',
#   'visa',
#   '缤纷生活',
#   '冬奥卡活',
#   '中银e盾',
#   '中银e令',
#   '手机银行',
#   'EMV白',
#   '征信行难',
#   '菜卡好错',
#   '非凡白设',
#   'sim盾',
#   '等级卡度',
#   '信用卡款',
#   '网贷核久',
#   '掌上生活',
#   '中银e贷',
#   '拉卡拉错',
#   '拉卡拉额',
#   '贷款批额',
#   '快贷易好',
#   '征信高债',
#   '乐享天天',
#   '无界卡批',
#   '借记卡易',
#   '积分不好',
#   '储蓄卡行',
#   '网捷贷期',
#   '乐分易绝',
#   '悠然白度',
#   '首卡度额',
#   '信用卡控',
#   '悠然白该',
#   '航空卡息',
#   '精粹白端',
#   '悠然白妥',
#   '乐分易能',
#   '携程卡发',
#   '犀利卡批',
#   '闪付额能',
#   '征信活活',
#   '联名卡心',
#   '支付宝卡',
#   '手机银行',
#   '功劳卡确',
#   '百夫长低',
#   '积分必要',
#   '掌上生活',
#   '掌上生活',
#   '附属卡额',
#   '信用卡额',
#   '积分不多',
#   '香格里拉',
#   '分期期单',
#   '香格里拉',
#   '积分不多',
#   '亲情卡额',
#   '分期低低',
#   '云闪付付',
#   '信用卡静',
#   '卡定额度',
#   '信用卡单',
#   '分期易额',
#   '分期不要',
#   'app度',
#   '精英白能',
#   '白金卡销',
#   '积分益高',
#   '南航标白',
#   '商友卡款',
#   '卡悔烦度',
#   '精英白费',
#   '金童卡能',
#   '贷款是息',
#   '分期金息',
#   '分期卡度',
#   '分期度快',
#   '信用卡度',
#   '信用卡度',
#   '香白银联',
#   '卡立度立',
#   '信用卡额',
#   '分期额款',
#   '信用卡妥',
#   '精英白费',
#   '附属卡额',
#   '分期MD',
#   '分期额多',
#   '惠民贷度',
#   '惠民贷度',
#   '沃尔玛金',
#   '征信好商',
#   '白金卡秀',
#   '白麒麟额',
#   '首卡信度',
#   'app怕',
#   '菜卡活错',
#   '马上金融',
#   '分期度期',
#   '闪付怪忧',
#   '白金卡级',
#   '新快现费',
#   '分期续费',
#   '白金卡活',
#   '卡子账号',
#   '卡低额额',
#   '信用卡批',
#   '华为套卡',
#   '贷款政期',
#   'i白金活',
#   '卡度活绝',
#   '征信款低',
#   '信用卡少',
#   'app度',
#   '手机银行',
#   '圆梦金息',
#   '快贷低息',
#   '分期度于',
#   '圆梦金少',
#   '圆梦金度',
#   '信用卡怨',
#   '信用卡苦',
#   '学生卡度',
#   '信用卡卡',
#   '信用卡点',
#   '白金卡好',
#   '白金卡行',
#   '信用卡奇',
#   '信用卡卡',
#   '卡缴款发',
#   '天天红包',
#   '信用卡处',
#   '信用卡点',
#   '普卡度顶',
#   '现金分期',
#   '传奇绿卡',
#   '分期路多',
#   '信用卡蛋',
#   '卡经病行',
#   '临时额度',
#   '临时额度',
#   '账单分期',
#   '掌上取现',
#   '现金分期',
#   '储蓄卡活',
#   '白金卡行',
#   '客服卡卡',
#   '金卡用久',
#   '六星客户',
#   '信用卡星',
#   '信用卡度',
#   '征信报告',
#   '多币账户',
#   'YE白卡',
#   '储蓄卡商',
#   '高铁贵宾',
#   '信用卡行',
#   '信用卡行',
#   '流水度高',
#   '信用卡白',
#   '信用卡户',
#   '信用卡绝',
#   '信用卡行',
#   '信用卡度',
#   '信用卡难',
#   '信用卡活',
#   '风控差活',
#   '客服差发',
#   '白金卡点',
#   '全球支付',
#   '金卡行度',
#   '借记卡看',
#   '储蓄行慢',
#   'app难',
#   '储蓄卡款',
#   '信用卡度',
#   '信用卡助',
#   '代发工资',
#   '理财定期',
#   '信用卡结',
#   '首卡多卡',
#   '征信行行',
#   '分期高低',
#   '卡度并卵',
#   '信用卡行',
#   '信用卡功',
#   '银行贷款',
#   '信用卡行',
#   '公务卡行',
#   '公务卡行',
#   '信用卡行',
#   '贷款舒服',
#   '信用卡批',
#   '信用卡期',
#   '信用卡难',
#   '信用卡期',
#   '支付有礼',
#   '大白金费',
#   '信用卡路',
#   '信用卡申',
#   '小额贷款',
#   '手机分期',
#   '征信报告',
#   '证券账户',
#   '经典白信',
#   '国航金卡',
#   '保诚保险',
#   '信用卡心',
#   '黑金卡信',
#   '信用卡信',
#   '白金卡销',
#   '支付宝信',
#   '白金卡度',
#   '储蓄卡难',
#   '卡了赘能',
#   '无界卡销',
#   '孝心白卡',
#   '公积金稚',
#   '菜卡销久',
#   'app活',
#   '无界活快',
#   '车主金融',
#   '车主卡香',
#   '信用卡动',
#   '掌上生活',
#   '存款费款',
#   '贷款怕暗',
#   '信用卡额',
#   '白金卡费',
#   '地方卡色',
#   '理财率点',
#   '公积金债',
#   '定制卡好',
#   '公积金多',
#   '金卡不到',
#   '鼎雅白行',
#   '支付宝付',
#   '积分卡黑',
#   '二类卡行',
#   '白金卡度',
#   '蚂蚁财富',
#   '分期固定',
#   '公积金水',
#   '白金卡卡',
#   '公积金够',
#   '贷款度高',
#   '信用卡能',
#   '信用卡度',
#   '支付宝储',
#   '征信期息',
#   '犀利卡谢',
#   '实体卡结',
#   '白金卡级',
#   '征信期期',
#   '大山白浩',
#   '菜卡语安',
#   '信用报告',
#   '好车主卡',
#   '公积金绝',
#   '理财较低',
#   '白金行储',
#   '鼎致白金',
#   '信用卡费',
#   '征信有核',
#   '定制卡高',
#   '积分难了',
#   '信用卡债',
#   '支付宝能',
#   '支付宝户',
#   '公积金久',
#   '定期期息',
#   '信用卡度',
#   '公积金够',
#   '信用卡行',
#   '网贷较低',
#   '芝麻信用',
#   '借记卡款',
#   '信用卡期',
#   '分期低化',
#   '分期有安',
#   '理财谱心',
#   '车主白品',
#   '积分费级',
#   'app白',
#   '公积金水',
#   '白金卡信',
#   '工会普卡',
#   '征信卡商',
#   '基金厉害',
#   '分期额卡',
#   'ae白期',
#   '理财少金',
#   '手机银行',
#   '京东金融',
#   '标准白行',
#   '生肖卡度',
#   '犀利卡了',
#   '分期额额'],
#  3: ['卡多额',
#   '储蓄卡',
#   '借记卡',
#   '储蓄卡',
#   '借记卡',
#   '信用卡',
#   '储蓄卡',
#   '房贷款',
#   '信用卡',
#   '储蓄卡',
#   '车主金',
#   '积分费',
#   '积分怪',
#   '钻石卡',
#   '白金卡',
#   'ae百',
#   '金葵花',
#   '信用卡',
#   '卡费费',
#   '经典白',
#   '云闪付',
#   '征信有',
#   '征信良',
#   '小白卡',
#   '小白卡',
#   '信用卡',
#   '额度高',
#   '黑羊金',
#   '信用卡',
#   '随行付',
#   '随行付',
#   '积分费',
#   '卡大了',
#   '私行卡',
#   '信用卡',
#   '经典白',
#   '信用卡',
#   'ae白',
#   '钻石卡',
#   '钻石卡',
#   '卡常行',
#   '分期费',
#   '网贷行',
#   '信用卡',
#   '征信心',
#   '大山白',
#   '腾讯金',
#   '闪付好',
#   '花呗期',
#   '分期费',
#   '分期款',
#   '退贷度',
#   '白金卡',
#   '金卡核',
#   '白金卡',
#   '贷款行',
#   '分期久',
#   '额度低',
#   '二卡累',
#   '工资卡',
#   '工资卡',
#   '菜卡发',
#   '白金卡',
#   '金卡低',
#   '白金信',
#   '白金卡',
#   '卡度少',
#   '金葵花',
#   '储蓄卡',
#   '储蓄卡',
#   '市民卡',
#   '花嫁卡',
#   '储蓄卡',
#   '手续费',
#   '分期高',
#   '征信债',
#   '逾期商',
#   '白金卡',
#   '白金卡',
#   '白金卡',
#   '白金卡',
#   '鸟白高',
#   '车主金',
#   '高铁白',
#   '借记卡',
#   '支付宝',
#   '首提度',
#   '滞纳金',
#   '违约金',
#   '信用卡',
#   '卡销谢',
#   '向日葵',
#   '朝朝盈',
#   '分期易',
#   '网贷低',
#   '黑青年',
#   '储蓄卡',
#   '财付通',
#   '财付通',
#   'app',
#   '鸟白额',
#   'E招贷',
#   'E分期',
#   '菜卡发',
#   '小白卡',
#   '分期额',
#   '积分好',
#   '积分费',
#   '积分卡',
#   '储蓄卡',
#   '朝朝盈',
#   '分期额',
#   '分期额',
#   '白条度',
#   '征信常',
#   '拉卡拉',
#   '公积金',
#   '公积金',
#   '房贷行',
#   '信用卡',
#   'app',
#   'app',
#   '菜卡提',
#   '经典白',
#   '公积金',
#   '经典白',
#   '车主白',
#   '基金大',
#   'i白金',
#   '征信额',
#   '二卡度',
#   '精致白',
#   '银行卡',
#   '信用卡',
#   '储蓄卡',
#   '储蓄卡',
#   'e招贷',
#   '小白卡',
#   '睿白金',
#   '信用卡',
#   '信用卡',
#   '利率以',
#   '信用卡',
#   '分期常',
#   '卡好了',
#   '经典白',
#   '储蓄卡',
#   '睿白金',
#   '生肖金',
#   '高端卡',
#   '白金卡',
#   '储蓄卡',
#   '信用卡',
#   '储蓄卡',
#   '积分常',
#   '信用卡',
#   '云闪付',
#   '金葵花',
#   '金葵花',
#   '金葵花',
#   '钻石卡',
#   '私行卡',
#   'app',
#   '银行卡',
#   'app',
#   '金葵花',
#   '贷款够',
#   '分期长',
#   '分期单',
#   '云闪付',
#   '积分烦',
#   '分期通',
#   '储蓄卡',
#   '理财益',
#   '金葵花',
#   '借记卡',
#   '信用卡',
#   '金葵花',
#   '社保卡',
#   '金葵花',
#   '公积金',
#   '储蓄卡',
#   '白金卡',
#   '白金卡',
#   '周周刷',
#   '公积金',
#   'app',
#   '公积金',
#   '信用卡',
#   '征信好',
#   '经典白',
#   '金葵花',
#   '信用卡',
#   '白金卡',
#   '金葵花',
#   '云闪付',
#   '网贷期',
#   '信用卡',
#   '白条期',
#   'app',
#   '卡常常',
#   '大白金',
#   '普卡度',
#   '大白金',
#   '大白金',
#   '信用卡',
#   '公积金',
#   '云闪付',
#   '云闪付',
#   '云闪付',
#   '云闪付',
#   '融e借',
#   '信用卡',
#   '云闪付',
#   '金白菜',
#   '云闪付',
#   '金白菜',
#   '分期行',
#   '征信户',
#   '征信能',
#   '征信期',
#   '征信有',
#   '信用卡',
#   '融e借',
#   '卡息行',
#   '分期期',
#   '信用卡',
#   '信用卡',
#   '分期烦',
#   '授信卡',
#   '续签卡',
#   '续费卡',
#   '卡救了',
#   '信用卡',
#   '云闪付',
#   '普卡度',
#   '实体卡',
#   '实体卡',
#   '支付宝',
#   '支付宝',
#   '卡度少',
#   '融e借',
#   '融e借',
#   '融e借',
#   '睡眠卡',
#   '二卡度',
#   '分期债',
#   '信用卡',
#   '征信度',
#   '分期谢',
#   '大白金',
#   'app',
#   '贷款批',
#   '融e借',
#   '信用卡',
#   '香白计',
#   '融e借',
#   '理财能',
#   '信用卡',
#   '信用卡',
#   '支付白',
#   '首卡度',
#   '信用卡',
#   '征信度',
#   '贷款批',
#   '信用卡',
#   '卡度错',
#   '信用卡',
#   '信用卡',
#   '金闪借',
#   '金闪借',
#   '白金卡',
#   '无界卡',
#   'U盾全',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '融e借',
#   '信用卡',
#   '无界卡',
#   '征信度',
#   '征信的',
#   '征信批',
#   '分期卡',
#   '教师白',
#   '卡销美',
#   '奋斗卡',
#   '卡不多',
#   '卡户怕',
#   '卡少度',
#   '融e借',
#   '融e借',
#   '信用卡',
#   '信用卡',
#   'app',
#   '融e借',
#   '融e借',
#   '首卡核',
#   '信用卡',
#   '违约金',
#   '信用卡',
#   '活期户',
#   '云闪付',
#   '分期惠',
#   '分期高',
#   '小额贷',
#   '信用卡',
#   '白条销',
#   '信用卡',
#   '网商贷',
#   '征信以',
#   '信用卡',
#   '信用卡',
#   '无界卡',
#   '分期批',
#   '分期度',
#   '信用卡',
#   '无界卡',
#   '信用卡',
#   '生肖白',
#   '年费行',
#   '公积金',
#   '首卡少',
#   '首卡行',
#   '香白活',
#   '分期行',
#   '分期好',
#   '分期质',
#   '运通卡',
#   '信用卡',
#   '首卡度',
#   '黄金卡',
#   '储蓄卡',
#   '无界卡',
#   '分期费',
#   '分期高',
#   '二代盾',
#   '蓝牙盾',
#   '精粹白',
#   '信用卡',
#   '理财行',
#   '信用卡',
#   '口令卡',
#   '征信心',
#   '信用卡',
#   '征信心',
#   '信用卡',
#   '环球白',
#   '环球白',
#   '卡以的',
#   'app',
#   '融e借',
#   '信用卡',
#   '融e借',
#   '军魂卡',
#   '奋斗卡',
#   '无界白',
#   '工银E',
#   '白金卡',
#   '卡悔了',
#   '征信户',
#   '卡行户',
#   '贷款批',
#   '首卡能',
#   '无界卡',
#   '融e借',
#   '融e借',
#   '融e借',
#   '信用卡',
#   '白金卡',
#   '白金卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '公积金',
#   '公积金',
#   '信用卡',
#   '贷款批',
#   '大武汉',
#   '大武汉',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '房贷信',
#   '新快现',
#   '信用卡',
#   '金卡好',
#   '公积金',
#   'app',
#   '理财多',
#   '理财多',
#   '支付宝',
#   '支付宝',
#   '信用卡',
#   '大白金',
#   '白金卡',
#   '分期算',
#   '分期期',
#   '融e借',
#   '卡活行',
#   '融e借',
#   '信用卡',
#   '公积金',
#   '黑财富',
#   '征信善',
#   '理财快',
#   '征信期',
#   '鼎极白',
#   '白金卡',
#   '白金卡',
#   'app',
#   '信用卡',
#   '信用卡',
#   'app',
#   'app',
#   '黑财富',
#   '支付宝',
#   '卡能金',
#   '信用卡',
#   'app',
#   '支付宝',
#   '信用卡',
#   '运通卡',
#   '融e借',
#   '征信度',
#   '贷款息',
#   '公积金',
#   '无界卡',
#   '卡度好',
#   '二卡度',
#   'app',
#   '标准白',
#   '简约白',
#   '信用卡',
#   '白金卡',
#   '小白金',
#   '信用卡',
#   '卡账额',
#   'app',
#   '口令卡',
#   '微众卡',
#   '白金卡',
#   '无界卡',
#   '融e借',
#   '金卡多',
#   'app',
#   '云闪付',
#   '信用卡',
#   '实体卡',
#   '生肖白',
#   '卡发通',
#   '白金卡',
#   '积分费',
#   '金卡度',
#   'app',
#   '融e借',
#   '星座卡',
#   '储蓄卡',
#   '征信期',
#   '征信账',
#   '征信期',
#   '卡常度',
#   '银行卡',
#   '信用卡',
#   '融e借',
#   '借记卡',
#   '信用卡',
#   '无界白',
#   '云闪付',
#   '云闪付',
#   '支付宝',
#   '余利宝',
#   '云闪付',
#   '支付宝',
#   '支付宝',
#   '支付宝',
#   '支付宝',
#   '支付宝',
#   '融e借',
#   '信用卡',
#   'U盾度',
#   '迷你白',
#   '无界白',
#   '储蓄卡',
#   '分期少',
#   '分期落',
#   '信用卡',
#   '信用卡',
#   '分期率',
#   '公积金',
#   '实体卡',
#   '星座卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   'app',
#   '理财户',
#   '支付宝',
#   '云闪付',
#   '房贷欢',
#   '征信度',
#   'app',
#   '云闪付',
#   '信用卡',
#   '医保卡',
#   '分期率',
#   '卡能额',
#   '融e借',
#   '信用卡',
#   '生肖金',
#   '白金卡',
#   '云闪付',
#   '云闪付',
#   '征信期',
#   '卡度高',
#   '支付宝',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '网贷常',
#   '信用卡',
#   '网贷期',
#   '征信好',
#   '网贷难',
#   'app',
#   '融e借',
#   '融e借',
#   '融e借',
#   '信用卡',
#   '公积金',
#   '支付宝',
#   '信用卡',
#   '银行卡',
#   '信用卡',
#   '储蓄卡',
#   '信用卡',
#   '融E借',
#   '储蓄卡',
#   '征信账',
#   '征信常',
#   '征信户',
#   '房贷批',
#   '工资卡',
#   '信用卡',
#   '信用卡',
#   '大白金',
#   '信用卡',
#   '储蓄卡',
#   '信用卡',
#   '储蓄卡',
#   '无界卡',
#   '无界卡',
#   '信用卡',
#   '信用卡',
#   '融e借',
#   '鼎致卡',
#   '信用卡',
#   '储蓄卡',
#   '分期度',
#   '信用卡',
#   '分期度',
#   '军魂卡',
#   '分期行',
#   '首卡度',
#   'E贷度',
#   '分期额',
#   '分期额',
#   '公务卡',
#   '车贷期',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '首卡好',
#   '信用卡',
#   '信用卡',
#   '积分行',
#   '支付宝',
#   '分期安',
#   '银行卡',
#   '分期息',
#   '信用卡',
#   '卡大上',
#   '支付宝',
#   '支付宝',
#   '信用卡',
#   '储蓄卡',
#   '云闪付',
#   '信用卡',
#   '信用卡',
#   '积分谢',
#   '信用卡',
#   '信用卡',
#   '借记卡',
#   '云闪付',
#   '信用卡',
#   '房贷仇',
#   '手机盾',
#   '卡度意',
#   '分期好',
#   '积分了',
#   '卡度要',
#   '信用卡',
#   '实体卡',
#   '卡发以',
#   '信用卡',
#   '支付宝',
#   'app',
#   'e贷硬',
#   '南航白',
#   '手机盾',
#   '自由白',
#   '储蓄卡',
#   '菜卡销',
#   '余额宝',
#   '征信账',
#   '征信白',
#   '房贷能',
#   '拉卡拉',
#   '拉卡拉',
#   '拉卡拉',
#   '房贷行',
#   '二卡易',
#   '理财行',
#   '活期少',
#   '征信批',
#   'e贷度',
#   '菜卡销',
#   '东航白',
#   '基金力',
#   '钻石卡',
#   '额度信',
#   '信用卡',
#   '信用卡',
#   '征信额',
#   '贷款行',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '公积金',
#   '燃梦白',
#   '信用卡',
#   '征信难',
#   '网贷期',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   'app',
#   '滞纳金',
#   '网捷贷',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '卡度高',
#   '悠然白',
#   '悠然白',
#   '信用卡',
#   '悠然白',
#   '悠悠白',
#   '无忧白',
#   '银行卡',
#   '房贷烦',
#   '信用卡',
#   '手续费',
#   '网贷卡',
#   '公积金',
#   '精粹白',
#   '首卡费',
#   '标准白',
#   '精英白',
#   '网贷债',
#   '信用卡',
#   '理财发',
#   '分期高',
#   '基金快',
#   '基金赚',
#   'app',
#   '基金久',
#   '贷款度',
#   '卡信死',
#   '支付宝',
#   '支付宝',
#   '分期金',
#   '信用卡',
#   '圆梦金',
#   '精英白',
#   '公积金',
#   '支付宝',
#   '信用卡',
#   '亲情卡',
#   'app',
#   '首卡卡',
#   '车主白',
#   '车主金',
#   '第一卡',
#   '卡度少',
#   '标白额',
#   '精英白',
#   '积分费',
#   '标白额',
#   '公积金',
#   '分期卡',
#   '分期生',
#   '手续费',
#   '卡级心',
#   '首卡发',
#   '信用卡',
#   '贷记卡',
#   '医护白',
#   '星座白',
#   '精英白',
#   '征信债',
#   '贷款债',
#   '支付宝',
#   '分期少',
#   '信用卡',
#   '卡行发',
#   '白金卡',
#   '分期单',
#   '分期单',
#   '卡度低',
#   '云闪付',
#   'app',
#   '标准白',
#   '白金卡',
#   '白金卡',
#   '标准白',
#   '标准白',
#   '标准白',
#   '白金卡',
#   '标准白',
#   '云闪付',
#   '经典白',
#   '分期度',
#   '征信额',
#   '积分常',
#   '基金慎',
#   '征信真',
#   '卡好点',
#   '精英白',
#   '精英白',
#   '分期提',
#   '信用卡',
#   '信用卡',
#   '副卡度',
#   '征信信',
#   '分期度',
#   '信用卡',
#   '信用卡',
#   '分期度',
#   '分期度',
#   '信用卡',
#   '征信生',
#   '信用卡',
#   '香白能',
#   '信用卡',
#   '犀利卡',
#   '积分度',
#   '附属卡',
#   '信用卡',
#   '白麒麟',
#   'app',
#   '银行卡',
#   '公积金',
#   'app',
#   '优衣拜',
#   '闪付能',
#   '白金卡',
#   '房贷淡',
#   '分期额',
#   '白麒麟',
#   '首卡度',
#   '钻石卡',
#   '麒麟白',
#   '白金卡',
#   '普卡度',
#   '公积金',
#   '黄金卡',
#   '分期息',
#   '网贷能',
#   '圆梦金',
#   '圆梦金',
#   '圆梦金',
#   '圆梦金',
#   '分期费',
#   '支付宝',
#   '圆梦金',
#   '信用卡',
#   '朝朝盈',
#   '卡度少',
#   '卡常绝',
#   '卡活绝',
#   '圆梦金',
#   '信用卡',
#   '圆梦金',
#   '分期度',
#   '分期度',
#   '圆梦金',
#   '征信户',
#   '圆梦金',
#   '首卡度',
#   '首卡销',
#   '公积金',
#   '分期款',
#   '金卡度',
#   '金卡有',
#   '新快现',
#   '新快现',
#   '圆梦金',
#   '卡费度',
#   '积分的',
#   '分期常',
#   '华为卡',
#   '储蓄卡',
#   '无界卡',
#   '白金费',
#   '小白金',
#   '白金卡',
#   '大白金',
#   '新快现',
#   'app',
#   '圆梦金',
#   '高利贷',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '经典白',
#   '经典白',
#   '信用卡',
#   '积分错',
#   '信用卡',
#   '新户礼',
#   '积分肋',
#   '信用卡',
#   '储蓄卡',
#   '信用卡',
#   '工资卡',
#   '储蓄卡',
#   '信用卡',
#   '信用卡',
#   '积分好',
#   '支付宝',
#   '刷卡率',
#   '贷款额',
#   'e招贷',
#   '账单日',
#   '负债率',
#   'E招贷',
#   '信用卡',
#   '信用卡',
#   '储蓄卡',
#   '信用卡',
#   '微信卡',
#   '账单日',
#   '信用卡',
#   '注销行',
#   '公积金',
#   '星座卡',
#   '信用卡',
#   '星座白',
#   '分期卡',
#   '信用卡',
#   '白金卡',
#   '信用卡',
#   '工资卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '公积金',
#   '纯白户',
#   '信用卡',
#   '储蓄卡',
#   '理财金',
#   '储蓄卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '白金卡',
#   'app',
#   '积分圾',
#   '普通卡',
#   '信用卡',
#   '大山白',
#   '大白山',
#   '白金卡',
#   '白金度',
#   '主卡活',
#   '主卡费',
#   '会员行',
#   '信用卡',
#   '航空卡',
#   '支付宝',
#   '财付通',
#   '储蓄卡',
#   '信用卡',
#   '信用卡',
#   '借记卡',
#   '芭比卡',
#   '工资卡',
#   '社保卡',
#   '信用卡',
#   '征信疵',
#   '芭比久',
#   '面签单',
#   '工资卡',
#   'etc',
#   '信用卡',
#   '信用卡',
#   '公务卡',
#   '学生卡',
#   '旅游卡',
#   '开卡难',
#   '额度升',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '耀红卡',
#   '取现金',
#   '网贷信',
#   '网贷常',
#   '负债率',
#   '信用卡',
#   '滞纳金',
#   '信用卡',
#   '分期现',
#   '大山白',
#   '积分啬',
#   '大山白',
#   '卡固定',
#   '账单日',
#   'c标白',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '房贷行',
#   '龙卡卡',
#   '蝙蝠白',
#   '信用卡',
#   '金卡免',
#   '违约金',
#   '分期惠',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '分期额',
#   '信用卡',
#   '网贷期',
#   '信用卡',
#   '二卡拒',
#   '芝麻分',
#   '储蓄卡',
#   '储蓄卡',
#   '信用卡',
#   '信用卡',
#   '储蓄卡',
#   '储蓄卡',
#   '工资卡',
#   '信用卡',
#   '信用卡',
#   '白金卡',
#   '信用卡',
#   '信用卡',
#   '信用卡',
#   '分期信',
#   '信用卡',
#   '普通卡',
#   '信用卡',
#   '信用卡',
#   '菜卡销',
#   '分期额',
#   '征信业',
#   '征信期',
#   '融e借',
#   '分期通',
#   '网捷贷',
#   '礼程白',
#   '金卡活',
#   '无界卡',
#   '支付宝',
#   '信用卡',
#   '多利卡',
#   '卡发度',
#   '公积金',
#   '贷款有',
#   '储蓄卡',
#   '卡久急',
#   '信用卡',
#   'app',
#   '多利金',
#   '卡行通',
#   '卡拉卡',
#   '菜卡发',
#   '精英白',
#   '卡打期',
#   '积分度',
#   '网贷安',
#   ...],
#  2: ['分期',
#   '首卡',
#   '分期',
#   '卡常',
#   '卡度',
#   '分期',
#   '首卡',
#   '积分',
#   '卡度',
#   '融资',
#   '双标',
#   '鸟白',
#   '鸟白',
#   '分期',
#   '分期',
#   '分期',
#   '卡提',
#   '征信',
#   'e卡',
#   '贷款',
#   '卡核',
#   '理财',
#   '征信',
#   '卡商',
#   '分期',
#   '分期',
#   '卡度',
#   '分期',
#   '分期',
#   '卡商',
#   '卡度',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '卡了',
#   '卡好',
#   '卡谱',
#   '征信',
#   '卡贵',
#   '积分',
#   '积分',
#   '卡全',
#   '卡发',
#   '卡绝',
#   '定期',
#   '卡额',
#   '首提',
#   '分期',
#   '分期',
#   '首提',
#   '金卡',
#   '卡多',
#   '分期',
#   '房贷',
#   '闪付',
#   '闪付',
#   '贷款',
#   '退款',
#   '分期',
#   '卡心',
#   '网贷',
#   '分期',
#   '分期',
#   '卡度',
#   '金卡',
#   '普卡',
#   '金卡',
#   '利息',
#   '分期',
#   '分期',
#   '卡度',
#   '卡难',
#   '网申',
#   '基金',
#   '菜卡',
#   '征信',
#   '征信',
#   '征信',
#   '积分',
#   '基金',
#   '积分',
#   '征信',
#   '普卡',
#   '理财',
#   '分期',
#   '分期',
#   '分期',
#   '利息',
#   '利息',
#   '利息',
#   '卡业',
#   '金卡',
#   '分期',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '菜卡',
#   '积分',
#   '分期',
#   '鸟白',
#   '贷款',
#   '分期',
#   '卡行',
#   '基金',
#   '定期',
#   '活期',
#   '基金',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '征信',
#   '征信',
#   '分期',
#   '分期',
#   '白条',
#   '征信',
#   '征信',
#   '征信',
#   '首卡',
#   '卡心',
#   '网贷',
#   '分期',
#   '分期',
#   '金卡',
#   '分期',
#   '分期',
#   '分期',
#   '白金',
#   '分期',
#   '积分',
#   '香白',
#   '征信',
#   '理财',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '减免',
#   '分期',
#   '利息',
#   '利息',
#   '分期',
#   '卡结',
#   '卡结',
#   '分期',
#   '车金',
#   '理财',
#   '分期',
#   '鸟白',
#   '卡级',
#   '鸟白',
#   '首卡',
#   '分期',
#   '分期',
#   '分期',
#   '积分',
#   '理财',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '闪付',
#   '闪付',
#   '积分',
#   '闪付',
#   '定期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '卡户',
#   '分期',
#   '分期',
#   '理财',
#   '菜卡',
#   '菜卡',
#   '普卡',
#   '征信',
#   '金卡',
#   '征信',
#   '首卡',
#   '卡露',
#   '卡度',
#   '鸟白',
#   '鸟白',
#   '金卡',
#   '理财',
#   '理财',
#   '金卡',
#   '理财',
#   '普卡',
#   '征信',
#   '卡期',
#   '卡期',
#   '花呗',
#   '卡度',
#   '卡多',
#   '卡行',
#   '卡行',
#   '卡销',
#   '卡能',
#   '香白',
#   '额度',
#   '二卡',
#   '征信',
#   '香白',
#   '房贷',
#   '菜卡',
#   '积分',
#   '征信',
#   '卡行',
#   '卡额',
#   '征信',
#   '分期',
#   '分期',
#   '征信',
#   '分期',
#   '分期',
#   '征信',
#   '征信',
#   '征信',
#   '卡户',
#   '金卡',
#   '卡常',
#   '首卡',
#   '卡快',
#   '卡活',
#   '卡行',
#   '卡行',
#   '卡行',
#   '卡度',
#   '菜卡',
#   '卡活',
#   '分期',
#   '二卡',
#   '二卡',
#   '征信',
#   '征信',
#   '征信',
#   '房贷',
#   '征信',
#   '房贷',
#   '二卡',
#   '卡能',
#   '分期',
#   '分期',
#   '首卡',
#   '卡功',
#   '贷款',
#   '贷款',
#   '理财',
#   '短债',
#   '征信',
#   '征信',
#   '贷款',
#   'U盾',
#   'U盾',
#   '分期',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '菜卡',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '卡发',
#   '卡控',
#   'U盾',
#   'U盾',
#   '房贷',
#   '金卡',
#   '二卡',
#   '理财',
#   'U盾',
#   'U盾',
#   '理财',
#   '理财',
#   '房贷',
#   '理财',
#   '理财',
#   '活期',
#   '理财',
#   '积分',
#   '分期',
#   '分期',
#   '分期',
#   '金卡',
#   '金卡',
#   '分期',
#   '贷款',
#   '花呗',
#   '借呗',
#   '贷款',
#   '卡度',
#   '房贷',
#   '卡债',
#   '征信',
#   '菜卡',
#   '理财',
#   '房贷',
#   '征信',
#   '分期',
#   '基金',
#   '卡度',
#   '首卡',
#   '年费',
#   '首卡',
#   '首卡',
#   '卡业',
#   '卡销',
#   '贷款',
#   '卡度',
#   '卡批',
#   '卡功',
#   '首卡',
#   '征信',
#   '征信',
#   'U盾',
#   '分期',
#   '分期',
#   '征信',
#   '征信',
#   '征信',
#   '征信',
#   '卡欢',
#   '卡活',
#   '菜卡',
#   '房贷',
#   '贷款',
#   '卡心',
#   '卡行',
#   '卡行',
#   '征信',
#   '分期',
#   '理财',
#   '理财',
#   '理财',
#   'U盾',
#   '理财',
#   '理财',
#   '理财',
#   '卡过',
#   '征信',
#   '首卡',
#   '首卡',
#   '快贷',
#   '白金',
#   '白金',
#   '贷款',
#   '贷款',
#   '贷款',
#   '贷款',
#   '贷款',
#   '金卡',
#   '首卡',
#   '卡户',
#   '网贷',
#   '贷款',
#   '贷款',
#   '分期',
#   '积分',
#   '普卡',
#   '普卡',
#   '理财',
#   '普卡',
#   '理财',
#   '卡度',
#   '普卡',
#   '龙腾',
#   '分期',
#   '卡行',
#   '分期',
#   '香白',
#   '小贷',
#   '网贷',
#   '分期',
#   '卡联',
#   '融资',
#   'U盾',
#   '积分',
#   '卡销',
#   '卡持',
#   '征信',
#   '积分',
#   '贷款',
#   '首卡',
#   '卡行',
#   '征信',
#   '首卡',
#   '征信',
#   '基金',
#   '定期',
#   '活期',
#   '香白',
#   '网贷',
#   '卡行',
#   'U盾',
#   'U盾',
#   '积分',
#   '积分',
#   '积分',
#   '金卡',
#   '征信',
#   '征信',
#   '贷款',
#   '征信',
#   '定期',
#   'U盾',
#   '贷款',
#   '征信',
#   '理财',
#   '二卡',
#   '按揭',
#   '卡气',
#   '理财',
#   '普卡',
#   '理财',
#   '理财',
#   '普卡',
#   '征信',
#   '征信',
#   '分期',
#   '分期',
#   '分期',
#   '龙腾',
#   '金卡',
#   '金卡',
#   '话费',
#   '油卡',
#   '积分',
#   '征信',
#   '征信',
#   '积分',
#   '征信',
#   '征信',
#   '卡功',
#   '卡凉',
#   '卡联',
#   '网贷',
#   '车贷',
#   '卡业',
#   '卡活',
#   '闪付',
#   '积分',
#   '积分',
#   '积分',
#   '闪付',
#   '积分',
#   '闪付',
#   '借呗',
#   '贷款',
#   '征信',
#   '基金',
#   '理财',
#   '贷款',
#   '分期',
#   '理财',
#   '房贷',
#   '网申',
#   '基金',
#   '房贷',
#   '征信',
#   '征信',
#   '分期',
#   'U盾',
#   '卡冻',
#   '首卡',
#   '征信',
#   '理财',
#   '征信',
#   '征信',
#   '分期',
#   '卡额',
#   '分期',
#   '征信',
#   '首卡',
#   '分期',
#   '分期',
#   '分期',
#   '征信',
#   '贷款',
#   '征信',
#   '分期',
#   '分期',
#   '征信',
#   '征信',
#   '首卡',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '二卡',
#   '分期',
#   '分期',
#   '分期',
#   '双标',
#   '卡心',
#   '积分',
#   '积分',
#   '积分',
#   '单标',
#   '单标',
#   '单标',
#   '赞卡',
#   '理财',
#   '分期',
#   '卡行',
#   '卡商',
#   '贷款',
#   '菜卡',
#   '卡度',
#   '房贷',
#   '卡用',
#   '积分',
#   '积分',
#   '征信',
#   '理财',
#   'U盾',
#   '贷款',
#   '二卡',
#   '网贷',
#   '菜卡',
#   '贷款',
#   '理财',
#   '白金',
#   '悠然',
#   '分期',
#   '积分',
#   '分期',
#   '征信',
#   '征信',
#   '贷款',
#   '征信',
#   '积分',
#   '卡活',
#   '理财',
#   '理财',
#   '征信',
#   '房贷',
#   '精粹',
#   '首卡',
#   '卡道',
#   '卡度',
#   '分期',
#   '分期',
#   '网贷',
#   '基金',
#   '按揭',
#   '卡易',
#   '房贷',
#   '卡度',
#   '卡便',
#   '卡有',
#   '网贷',
#   '征信',
#   '基金',
#   '房贷',
#   '房贷',
#   '房贷',
#   '基金',
#   '房贷',
#   '房贷',
#   '按揭',
#   '卡躁',
#   '基金',
#   '分期',
#   '贷款',
#   '贷款',
#   '网贷',
#   '征信',
#   '征信',
#   '双标',
#   '双标',
#   '卡度',
#   '征信',
#   '卡心',
#   '白金',
#   '卡发',
#   '网贷',
#   '征信',
#   '网贷',
#   '基金',
#   '基金',
#   '基金',
#   '分期',
#   '分期',
#   '分期',
#   '卡气',
#   '基金',
#   '卡心',
#   '卡累',
#   '卡慢',
#   '契税',
#   '卡度',
#   '分期',
#   '分期',
#   '卡销',
#   '卡活',
#   '卡活',
#   '日息',
#   '分期',
#   '卡行',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '标白',
#   '下卡',
#   '分期',
#   '积分',
#   '标白',
#   '下卡',
#   '征信',
#   '卡户',
#   '卡度',
#   '分期',
#   '分期',
#   '分期',
#   '卡良',
#   '贷款',
#   '卡大',
#   '分期',
#   '二卡',
#   '网贷',
#   '积分',
#   '征信',
#   '分期',
#   '分期',
#   '分期',
#   '卡足',
#   '标准',
#   '分期',
#   '分期',
#   '分期',
#   '卡准',
#   '卡慢',
#   '卡费',
#   '卡费',
#   '理财',
#   '金卡',
#   '标准',
#   '标准',
#   '标准',
#   '分期',
#   '白条',
#   '分期',
#   '分期',
#   '房贷',
#   '积分',
#   '分期',
#   '卡额',
#   '分期',
#   '征信',
#   '卡度',
#   '分期',
#   '分期',
#   '积分',
#   '积分',
#   '分期',
#   '负债',
#   '负债',
#   '征信',
#   '分期',
#   '贷款',
#   '分期',
#   '卡生',
#   '分期',
#   '分期',
#   '提额',
#   '征信',
#   '香白',
#   '二卡',
#   '分期',
#   '贷款',
#   '龙腾',
#   '积分',
#   '积分',
#   '征信',
#   '香白',
#   '卡活',
#   '征信',
#   '分期',
#   '分期',
#   '贷款',
#   '征信',
#   '金卡',
#   '油卡',
#   '卡能',
#   '贷款',
#   '分期',
#   '房贷',
#   '房贷',
#   '分期',
#   '分期',
#   '卡度',
#   '金卡',
#   '白金',
#   '征信',
#   '卡心',
#   '菜卡',
#   '卡发',
#   '金卡',
#   '普卡',
#   '普卡',
#   '基金',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '分期',
#   '网贷',
#   '美团',
#   '钱站',
#   '征信',
#   '分期',
#   '卡活',
#   '卡活',
#   '卡度',
#   '普卡',
#   '卡行',
#   '分期',
#   '分期',
#   '分期',
#   '理财',
#   '分期',
#   '理财',
#   '分期',
#   '卡业',
#   '理财',
#   '卡额',
#   '网贷',
#   '网贷',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '金卡',
#   '分期',
#   '卡大',
#   '金卡',
#   '征信',
#   '卡惑',
#   '理财',
#   '白金',
#   'i白',
#   '首卡',
#   '卡能',
#   '网贷',
#   '分期',
#   '白金',
#   '卡度',
#   '金卡',
#   '积分',
#   '积分',
#   '分期',
#   '卡度',
#   '卡度',
#   '征信',
#   '卡度',
#   '卡度',
#   '分期',
#   '分期',
#   '普卡',
#   '金卡',
#   '新卡',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '分期',
#   '客服',
#   '分期',
#   '分期',
#   '利润',
#   '额度',
#   '临额',
#   '固额',
#   '积分',
#   '账单',
#   '账单',
#   '账单',
#   '账单',
#   '卡行',
#   '年费',
#   '年费',
#   '金额',
#   '积分',
#   '房产',
#   '车产',
#   '卡度',
#   '理财',
#   '基金',
#   '套现',
#   '取现',
#   '注销',
#   '注销',
#   '注销',
#   '征信',
#   '流水',
#   '代发',
#   '积分',
#   '年费',
#   '积分',
#   '年费',
#   '白户',
#   '分期',
#   '支付',
#   '年费',
#   '年费',
#   '普卡',
#   '二卡',
#   '金卡',
#   '金卡',
#   '普卡',
#   '首卡',
#   '授权',
#   '分期',
#   '卡活',
#   '卡用',
#   '积分',
#   '积分',
#   '客服',
#   '年费',
#   '借呗',
#   '花呗',
#   '金条',
#   '白条',
#   '白金',
#   '副卡',
#   '主卡',
#   '副卡',
#   '会员',
#   '会员',
#   '房贷',
#   '车卡',
#   '快贷',
#   '微信',
#   '卡行',
#   '车卡',
#   '面签',
#   '卡惠',
#   '白金',
#   '开卡',
#   '房贷',
#   '龙卡',
#   '金卡',
#   '利息',
#   '积分',
#   '卡度',
#   '征信',
#   '分期',
#   '卡怕',
#   '金卡',
#   '金卡',
#   '卡早',
#   '普卡',
#   '注销',
#   '征信',
#   '还款',
#   '还款',
#   '账单',
#   '分期',
#   '颜卡',
#   '卡效',
#   '客服',
#   '资金',
#   '年费',
#   '年费',
#   '卡敢',
#   '客服',
#   '利息',
#   '卡期',
#   '福卡',
#   '征信',
#   '征信',
#   '网贷',
#   '快贷',
#   '理财',
#   '花呗',
#   '借呗',
#   '分期',
#   '网贷',
#   '分期',
#   '卡久',
#   '征信',
#   '网贷',
#   '菜卡',
#   '分期',
#   '积分',
#   '卡久',
#   '征信',
#   '卡度',
#   '卡安',
#   '贷款',
#   '分期',
#   '分期',
#   '贷款',
#   '积分',
#   '积分',
#   '征信',
#   '卡动',
#   '征信',
#   '分期',
#   '基金',
#   '金卡',
#   '房贷',
#   '分期',
#   '分期',
#   '卡业',
#   '鼎雅',
#   '鼎致',
#   '积分',
#   '征信',
#   '鼎雅',
#   '征信',
#   '理财',
#   '菜卡',
#   '卡心',
#   '鼎雅',
#   '首卡',
#   '卡活',
#   '积分',
#   '积分',
#   '积分',
#   '积分',
#   '分期',
#   '分期',
#   '分期',
#   '积分',
#   '金卡',
#   '卡亮',
#   '积分',
#   '分期',
#   '理财',
#   '白条',
#   '贷款',
#   '借呗',
#   '基金',
#   '积分',
#   '积分',
#   '积分',
#   '房贷',
#   '理财',
#   '网贷',
#   '白金',
#   '理财',
#   '基金',
#   '鼎雅',
#   '鼎致',
#   '征信',
#   '分期',
#   '积分',
#   '积分',
#   '理财',
#   '理财',
#   '理财',
#   '分期',
#   '网贷',
#   '分期',
#   '定期',
#   '活期',
#   '理财',
#   '金卡',
#   '积分',
#   '分期',
#   '网申',
#   '卡理',
#   '基金',
#   '理财',
#   '基金',
#   '分期',
#   '积分',
#   '征信',
#   '房贷',
#   '金卡',
#   '普卡',
#   '理财',
#   '基金',
#   '卡行',
#   '龙卡',
#   ...],
#  1: ['卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '盾',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡',
#   '卡']}

# %% [markdown]
# ## 实体数据增强
# 我们需要遍历训练集中每一行，然后以`0.5`的概率决定是否对其进行数据增强。
# * 如果要增强，那么我们就获取其中所有实体。
#     -  如果此行没有实体，那我们就随机删除其中几个`O`。
#     - 如果此行有实体，那我们用相同长度的其他实体随机替换掉其中的一个实体，然后随机重复几次。
# * 如果不增强，则跳过此行。

# %%
from random import randint
kinds = ['PRODUCT', 'COMMENTS_ADJ', 'COMMENTS_N', 'BANK']

def get_random_replace(dic, length):
    idx = randint(1, len(dic[length])-1)
    return dic[length][idx]

def get_augment(data, row):
    
    if not randint(1, 10)%3:    # 70%增强
        return None
    labels = data['BIO_anno'][row].split(' ')
    text = list(data['text'][row])
    i = 0
    while i < len(labels):
        label = labels[i]
        if any((kind in label for kind in kinds)) and label.startswith('B-'):      # label中有实体且是以B-开头的
            j = i
            while labels[j][2:] != label[2:]:             # 找出当前实体范围
                j += 1
            length = j - i
            if length in eval(label[2:]).keys():
                text[i:j] = get_random_replace(eval(label[2:]), j-i)     # label[2:] : 去掉 B- 和 I- 的剩余部分
                i = j
            else:
                i += 1
            if randint(1, 10)%2:        # 50%概率不继续替换
                return text, labels
        else:
            num_delete = randint(1, len(text)-1)       # 随机删除的数量
            for i in range(num_delete):
                idx = randint(0, num_delete-1)           # 删除的位置
                text = text[:idx] + text[idx+1:]
                labels = labels[:idx] + labels[idx+1:]
                if not randint(1, 10)%3:
                    return text, labels
            return text, labels

augmented_data = train_data[['text', 'BIO_anno']]
n = len(train_data)
for row in range(n):
    new = get_augment(augmented_data, row)
    if not new:
        continue
    new_text, label = new
    augmented_data.loc[len(augmented_data), ['text', 'BIO_anno']] = ''.join(new_text), ' '.join(label)
print(label)
# Out:
# /tmp/ipykernel_268843/3215866397.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   augmented_data.loc[len(augmented_data), ['text', 'BIO_anno']] = ''.join(new_text), ' '.join(label)
# ['B-BANK', 'I-BANK', 'I-BANK', 'I-BANK', 'I-BANK', 'O', 'B-BANK', 'I-BANK', 'I-BANK', 'I-BANK', 'O', 'B-BANK', 'I-BANK', 'I-BANK', 'I-BANK', 'O', 'O']

# %%
AUGMENTED_DATA_PATH = '/project1/liqingshan/NLP/NER/Data/' + 'augmented_data.csv'
augmented_data.to_csv(AUGMENTED_DATA_PATH)
augmented_data
# Out:
#                                            text  \
# 0                         挺快的了，我是8月底下的卡，今年51提的。
# 1                    我显示汇总过高了，今天下了中信4万，准备把招商注销了
# 2                                      刷超市银行利润低
# 3                               你这个网速是怎么加的呢，慢死了
# 4      我12月份下的卡，一直有临额今天到期临时额度没有了，这个月刚好是调额月，怕进黑屋
# ...                                         ...
# 10199                     审取消是叫你申低等级的卡??金普卡基本秒批
# 10200                          等等我卡到了，还现什么进展。焦虑
# 10201               一打一个准，准胜，看激活信用卡时协议，全是对银行有利的
# 10202                                ，额度还行吧没毕业哦
# 10203                         张家港农商、江阴农商、无锡农商试试
#
#                                                 BIO_anno
# 0      B-COMMENTS_ADJ I-COMMENTS_ADJ O O O O O O O O ...
# 1      O O O O O B-COMMENTS_ADJ I-COMMENTS_ADJ O O O ...
# 2                           O O O O O O O B-COMMENTS_ADJ
# 3             O O O O O O O O O O O O B-COMMENTS_ADJ O O
# 4      O O O O O O O B-PRODUCT O O O O B-COMMENTS_N I...
# ...                                                  ...
# 10199          O O O O O O O O O O O O O O O O O O O O O
# 10200  O O O O O O O O O O O O O O B-COMMENTS_ADJ I-C...
# 10201  O O O O O O O O O O B-COMMENTS_N I-COMMENTS_N ...
# 10202          O B-COMMENTS_N I-COMMENTS_N O O O O O O O
# 10203  B-BANK I-BANK I-BANK I-BANK I-BANK O B-BANK I-...
#
# [10204 rows x 2 columns]

# %% [markdown]
# 可以看到，经过数据增强，我们得到了额外的4246条数据。接下来我们用新生成的数据训练，然后在测试集上实验。
